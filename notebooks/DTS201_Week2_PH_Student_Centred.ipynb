# %% [markdown]
# <a href="https://colab.research.google.com/github/davemma85-code/OOU_DTS201_Introduction_to_Data_Science/blob/main/notebooks/DTS201_Week2_PH_Student_Centred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DTS 201 – Introduction to Data Science
# ## Week 2 Practical (PH): Data Collection, Cleaning, and Quality Assessment
#
# **Instructor:** Dr. Sakinat Folorunso
# **Title:** Associate Professor of AI Systems and FAIR Data
# **Department:** Computer Sciences, Olabisi Onabanjo University, Ago-Iwoye, Ogun State, Nigeria
#
# ---
#
# ### 🎯 Practical Learning Objectives (Week 2)
#
# By the end of this practical session, you should be able to:
#
# - Collect data from multiple sources (manual entry, web files, shared documents).
# - Import and combine raw datasets using Python (CSV, Excel, TXT).
# - Detect common data quality problems (missing values, inconsistent labels, wrong data types).
# - Clean and standardize real-world data for analysis.
# - Apply basic validation checks to ensure the correctness and reliability of your dataset.
#
# > 💡 **This notebook is highly student-centred.** You will perform each task hands-on, modify the code, interpret results, and submit your own reflections.

# %% [markdown]
# ## 1. Getting Started: Where Will Your Data Come From?
#
# In this practical, you will practice collecting datasets from these common sources:
#
# 1. **Files downloaded from the web** (CSV, XLSX).
# 2. **Manual entry**, where you create a DataFrame from scratch.
# 3. **Shared departmental data** (provided by your lecturer).
#
# You may work with:
#
# - Your own dataset
# - The sample datasets provided
# - Or create a small dataset of your own

# %% [markdown]
# ### 1.1 Optional: Mount Google Drive (If Using Colab)

# %%
# Run this only if using Google Colab AND your dataset is stored on Google Drive.

# Import tool for mounting Google Drive into Colab
from google.colab import drive

# Mount your Google Drive — follow the instructions when you run this
drive.mount('/content/drive')

# After mounting, your files become accessible under '/content/drive/MyDrive/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Importing Required Libraries

# %%
# pandas: primary library for working with data tables
import pandas as pd

# Import the pandas library for working with tabular data (rows and columns)
import pandas as pd

# Import numpy for numerical operations (we may need it later)
import numpy as np

# Import matplotlib for basic plotting (optional for this week but useful generally)
import matplotlib.pyplot as plt

# Configure matplotlib so that any plots appear inside the notebook
# %matplotlib inline

# %% [markdown]
# ## 3. Collecting and Importing Raw Datasets
#
# We will work with datasets that may contain:
#
# - Typos
# - Missing values
# - Inconsistent labels
# - Duplicate entries
# - Wrong data types
#
# You will load three datasets:
#
# - A **CSV** file
# - An **Excel** file
# - A **TXT** / delimited file

# %% [markdown]
# ### 3.1 Importing a CSV File

# %%
# Replace 'raw_students.csv' with your real CSV file name
csv_path = '/content/drive/My Drive/DTS201/sales_data.csv'  # TODO: change this

# Load CSV file
df_csv = pd.read_csv(csv_path)  # Reads CSV into DataFrame

# View sample rows
df_csv.head()  # Look at the first few rows to inspect raw structure
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ### 3.2 Importing an Excel File

# %%
# Replace 'raw_sales.xlsx' with your Excel file
excel_path = '/content/drive/My Drive/DTS201/Sales_data.xlsx'  # TODO: change this

# Read Excel file — automatically loads the first sheet
df_excel = pd.read_excel(excel_path)

df_excel.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...           â‚¹399
# 1  Computers&Accessories|Accessories&Peripherals|...           â‚¹199
# 2  Computers&Accessories|Accessories&Peripherals|...           â‚¹199
# 3  Computers&Accessories|Accessories&Peripherals|...           â‚¹329
# 4  Computers&Accessories|Accessories&Peripherals|...           â‚¹154
#
#   actual_price  discount_percentage rating rating_count  \
# 0     â‚¹1,099                 0.64    4.2        24269
# ...

# %% [markdown]
# ### 3.3 Importing a TXT / Delimited File

# %%
txt_path = '/content/drive/My Drive/DTS201/Sales_data.txt'  # TODO: change

# Load a text file separated by commas or tabs
df_txt = pd.read_csv(txt_path, delimiter="\t")  # Modified delimiter to tab

df_txt.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
txt_path = '/content/drive/My Drive/DTS201/Sales_data.txt'

# Read and display the first 10 lines of the file to inspect its structure
with open(txt_path, 'r') as f:
    for i, line in enumerate(f):
        print(f"Line {i+1}: {line.strip()}")
        if i == 9: # Display only the first 10 lines
            break
# Out:
# Line 1: product_id	product_name	category	discounted_price	actual_price	discount_percentage	rating	rating_count	about_product	user_id	user_name	review_id	review_title	review_content	img_link	product_link
# ...

# %% [markdown]
# > ✏️ **Student Task:**
# > For each dataset (CSV, Excel, TXT):
# > 1. State what the rows represent.
# > 2. Identify at least 3 columns.
# > 3. Explain which dataset looks “cleanest” and which looks “messiest.”

# %% [markdown]
# ## 4. Assessing Data Quality

# %% [markdown]
# ### 4.1 Checking for Missing Values

# %%
# Count missing values per column
df_csv.isnull().sum()  # Repeat for df_excel and df_txt
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
import seaborn as sns
# Visualizing missing values
plt.figure(figsize=(10,5))
sns.heatmap(df_csv.isnull(), cbar=False)
plt.title("Missing Values in CSV Dataset")
plt.show()

# %% [markdown]
# ### 4.2 Checking for Inconsistent Categories

# %%
# Replace 'Gender' with your own column
df_csv['category'].unique()  # Check unique values (look for typos or variants)
# Out:
# array(['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables',
#        'Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|RemoteControls',
#        'Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables',
#        'Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables',
#        'Electronics|HomeTheater,TV&Video|Projectors',
#        'Electronics|HomeAudio|Accessories|Adapters',
# ...

# %% [markdown]
# ### 4.3 Detecting Wrong Data Types

# %%
# Inspect column data types
df_csv.dtypes  # Identify numerical columns stored as text
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# > ✏️ **Student Reflection:**
# > - Identify 2 data quality issues in any of the datasets.
# > - Describe why each issue would create problems during analysis.

# %% [markdown]
# ## 5. Cleaning and Standardizing Data

# %% [markdown]
# ### 5.1 Handling Missing Values

# %%
# Handle 'rating_count' column, which has missing values and is of object type.
# First, remove commas and convert to numeric, coercing errors.
# The `str.replace` method is used to remove commas from the string representation of numbers.
# `pd.to_numeric` converts the cleaned strings to actual numbers, setting unconvertible values to NaN.
df_csv['rating_count'] = df_csv['rating_count'].astype(str).str.replace(',', '', regex=True)
df_csv['rating_count'] = pd.to_numeric(df_csv['rating_count'], errors='coerce')

# Now, fill missing numerical values with the median of 'rating_count'
df_csv['rating_count'] = df_csv['rating_count'].fillna(df_csv['rating_count'].median())

# Display the sum of nulls for verification
print("Missing values after filling 'rating_count':")
print(df_csv['rating_count'].isnull().sum())
# Out:
# Missing values after filling 'rating_count':
# 0

# %% [markdown]
# ### 5.2 Correcting Wrong Data Types

# %%
# Convert 'discounted_price' and 'actual_price' columns to numeric
# First, remove the currency symbol '₹' and commas, then convert to numeric
df_csv['discounted_price'] = df_csv['discounted_price'].astype(str).str.replace('₹', '', regex=False).str.replace(',', '', regex=True)
df_csv['actual_price'] = df_csv['actual_price'].astype(str).str.replace('₹', '', regex=False).str.replace(',', '', regex=True)
df_csv['discounted_price'] = pd.to_numeric(df_csv['discounted_price'], errors='coerce')
df_csv['actual_price'] = pd.to_numeric(df_csv['actual_price'], errors='coerce')

# Convert 'discount_percentage' to numeric (remove '%' and divide by 100)
df_csv['discount_percentage'] = df_csv['discount_percentage'].astype(str).str.replace('%', '', regex=False)
df_csv['discount_percentage'] = pd.to_numeric(df_csv['discount_percentage'], errors='coerce') / 100

# Convert 'rating' to numeric
df_csv['rating'] = pd.to_numeric(df_csv['rating'], errors='coerce')

print("Data types after conversion:")
print(df_csv[['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']].dtypes)
# Out:
# Data types after conversion:
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# dtype: object

# %% [markdown]
# ### 5.3 Standardizing Category Labels

# %%
# Example: Standardize variations of 'Male'
df_csv['Gender'] = df_csv['Gender'].str.lower().replace({'m': 'male', 'male ': 'male'})

# %% [markdown]
# ### 5.4 Removing Duplicates

# %%
# Count duplicates
df_csv.duplicated().sum()

# Remove them
df_csv = df_csv.drop_duplicates()

# %% [markdown]
# > ✏️ **Student Task:**
# > Apply *at least three* cleaning techniques to any dataset.
# > Write a short explanation of what you cleaned and why.

# %% [markdown]
# ## 6. Summary of Week 2 Practical
#
# In this week’s PH, you:
# - Collected multiple raw datasets.
# - Imported CSV, Excel, and TXT files.
# - Detected missing values, wrong types, and inconsistent categories.
# - Cleaned the data using standard techniques.
#
# > 🧠 **Final Reflection:**
# > Which cleaning step was the most useful, and which dataset needed the most work?

# %% [markdown]
# # Task
# Add an inconsistent 'Gender' column to `df_csv`, then modify the code in cell `607d6cf9` to standardize this new 'Gender' column by converting all entries to lowercase and mapping variations like 'm', 'M', 'male ' to 'male' and 'f', 'F', 'female ' to 'female'. After modification, execute the cell to demonstrate the data cleaning process.

# %% [markdown]
# ## Add Inconsistent 'Gender' Column
#
# ### Subtask:
# Create a new 'Gender' column in `df_csv` and populate it with sample data that includes inconsistent entries (e.g., 'male', 'female', 'M', 'FEMALE', 'male ', 'm', 'f') to demonstrate data standardization.

# %% [markdown]
# **Reasoning**:
# To fulfill the subtask, I need to create a new 'Gender' column in `df_csv` with inconsistent entries. This involves generating random gender data and assigning it to the new column.

# %%
import numpy as np

# Generate sample inconsistent gender data
gender_options = ['male', 'female', 'M', 'FEMALE', 'male ', 'm', 'f', np.nan]
sample_gender_data = np.random.choice(gender_options, size=len(df_csv))

# Add the new 'Gender' column to df_csv
df_csv['Gender'] = sample_gender_data

# Display the first few rows of df_csv including the new 'Gender' column
print("DataFrame head with new 'Gender' column:")
print(df_csv.head())

# Display the unique values and their counts in the new 'Gender' column
print("\nUnique values and counts in 'Gender' column:")
print(df_csv['Gender'].value_counts(dropna=False))
# Out:
# DataFrame head with new 'Gender' column:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# ...

# %% [markdown]
# **Reasoning**:
# The 'Gender' column has been added with inconsistent values. Now, I need to modify the code in cell `607d6cf9` to standardize these entries by converting them to lowercase and mapping variations to 'male' or 'female'.

# %%
df_csv['Gender'] = df_csv['Gender'].astype(str).str.lower().str.strip()
df_csv['Gender'] = df_csv['Gender'].replace({'m': 'male', 'f': 'female', 'female ': 'female', 'male ': 'male', 'nan': np.nan})

print("Unique values and counts in 'Gender' column after standardization:")
print(df_csv['Gender'].value_counts(dropna=False))
# Out:
# Unique values and counts in 'Gender' column after standardization:
# Gender
# male      742
# female    529
# NaN       194
# Name: count, dtype: int64

# %% [markdown]
# ## Standardize 'Gender' Column
#
# ### Subtask:
# Modify the existing cell `607d6cf9` to apply standardization techniques (converting to lowercase and replacing variations with a consistent 'male' or 'female') to the newly added 'Gender' column in `df_csv`. After modification, the cell will be executed.

# %% [markdown]
# **Reasoning**:
# The user wants to modify the code in cell `607d6cf9` to standardize the 'Gender' column by converting it to lowercase, stripping whitespace, and mapping inconsistent entries to 'male' or 'female', and 'nan' strings to actual NaN values. This code will replace the existing content of cell `607d6cf9` and verify the standardization by printing unique values and their counts.

# %%
df_csv['Gender'] = df_csv['Gender'].astype(str).str.lower().str.strip()
df_csv['Gender'] = df_csv['Gender'].replace({'m': 'male', 'f': 'female', 'female ': 'female', 'male ': 'male', 'nan': np.nan})

print("Unique values and counts in 'Gender' column after standardization:")
print(df_csv['Gender'].value_counts(dropna=False))
# Out:
# Unique values and counts in 'Gender' column after standardization:
# Gender
# male      742
# female    529
# NaN       194
# Name: count, dtype: int64

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the 'Gender' column has been added and successfully standardized, addressing the original KeyError and demonstrating the cleaning process.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   An inconsistent 'Gender' column was successfully added to the `df_csv` DataFrame, containing variations such as 'male', 'female', 'M', 'FEMALE', 'male ', 'm', 'f', and `np.nan`.
# *   The 'Gender' column was subsequently standardized by converting all entries to lowercase, stripping whitespace, and mapping inconsistent values ('m', 'f') to 'male' or 'female', respectively. String 'nan' values were also converted to `np.nan`.
# *   After standardization, the unique values in the 'Gender' column were consolidated into 'male', 'female', and `NaN`, with specific counts of 742 for 'male', 529 for 'female', and 194 for `NaN` values.
#
# ### Insights or Next Steps
# *   The successful standardization of the 'Gender' column demonstrates an effective data cleaning process for categorical variables, crucial for accurate analysis and model training.
# *   The cleaned 'Gender' column is now consistent and ready for use in further analysis, such as demographic breakdowns or feature engineering, without issues caused by varied spellings or cases.
